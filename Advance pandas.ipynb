# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Shashank\\Documents\\pokemon.csv")

# %%
df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[df['Generation'] == 1]
# Out:
#        #           Name   Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1      Bulbasaur    Grass    Poison   45      49       49       65
# 1      2        Ivysaur    Grass    Poison   60      62       63       80
# 2      3       Venusaur    Grass    Poison   80      82       83      100
# 3      4  Mega Venusaur    Grass    Poison   80     100      123      122
# 4      5     Charmander     Fire       NaN   39      52       43       60
# ..   ...            ...      ...       ...  ...     ...      ...      ...
# 161  162      Dragonite   Dragon    Flying   91     134       95      100
# 162  163         Mewtwo  Psychic       NaN  106     110       90      154
# 163  164  Mega Mewtwo X  Psychic  Fighting  106     190      100      154
# 164  165  Mega Mewtwo Y  Psychic       NaN  106     150       70      194
# 165  166            Mew  Psychic       NaN  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
print(df[df.index.notnull()])
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[df['Legendary'] == True]
# Out:
#        #            Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 156  157        Articuno       Ice    Flying   90      85      100       95
# 157  158          Zapdos  Electric    Flying   90      90       85      125
# 158  159         Moltres      Fire    Flying   90     100       90      125
# 162  163          Mewtwo   Psychic       NaN  106     110       90      154
# 163  164   Mega Mewtwo X   Psychic  Fighting  106     190      100      154
# ..   ...             ...       ...       ...  ...     ...      ...      ...
# 795  796         Diancie      Rock     Fairy   50     100      150      100
# 796  797    Mega Diancie      Rock     Fairy   50     160      110      160
# 797  798  Hoopa Confined   Psychic     Ghost   80     110       60      150
# 798  799   Hoopa Unbound   Psychic      Dark   80     160       60      170
# 799  800       Volcanion      Fire     Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df[df['Legendary'] == True]
# Out:
#        #            Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 156  157        Articuno       Ice    Flying   90      85      100       95
# 157  158          Zapdos  Electric    Flying   90      90       85      125
# 158  159         Moltres      Fire    Flying   90     100       90      125
# 162  163          Mewtwo   Psychic       NaN  106     110       90      154
# 163  164   Mega Mewtwo X   Psychic  Fighting  106     190      100      154
# ..   ...             ...       ...       ...  ...     ...      ...      ...
# 795  796         Diancie      Rock     Fairy   50     100      150      100
# 796  797    Mega Diancie      Rock     Fairy   50     160      110      160
# 797  798  Hoopa Confined   Psychic     Ghost   80     110       60      150
# 798  799   Hoopa Unbound   Psychic      Dark   80     160       60      170
# 799  800       Volcanion      Fire     Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df1 = df[df['Legendary'] == True]

# %%
leg_pok = df1['Type 1'].value_counts()
print(leg_pok)
# Out:
# Psychic     14
# Dragon      12
# Fire         5
# Electric     4
# Rock         4
# Water        4
# Ground       4
# Steel        4
# Grass        3
# Flying       2
# Ice          2
# Dark         2
# Normal       2
# Ghost        2
# Fairy        1
# Name: Type 1, dtype: int64

# %%
h = leg_pok.idxmax()

# %%
print(h)
# Out:
# Psychic

# %%
df1 = df[df['Type 2'].isnull()]

# %%
print(df1)
# Out:
#        #        Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      5  Charmander    Fire    NaN   39      52       43       60       50
# 5      6  Charmeleon    Fire    NaN   58      64       58       80       65
# 9     10    Squirtle   Water    NaN   44      48       65       50       64
# 10    11   Wartortle   Water    NaN   59      63       80       65       80
# 11    12   Blastoise   Water    NaN   79      83      100       85      105
# ..   ...         ...     ...    ...  ...     ...      ...      ...      ...
# 775  776     Sliggoo  Dragon    NaN   68      75       53       83      113
# 776  777      Goodra  Dragon    NaN   90     100       70      110      150
# 788  789    Bergmite     Ice    NaN   55      69       85       32       35
# 789  790     Avalugg     Ice    NaN   95     117      184       44       46
# 792  793     Xerneas   Fairy    NaN  126     131       95      131       98
#
#      Speed  Generation  Legendary
# ...

# %%
len(df1[df1['Legendary'] == True])
# Out:
# 25

# %%
df2 = df[df['Type 2'].isnull() & df['Legendary'] == True]

# %%
df2
# Out:
#        #                      Name    Type 1 Type 2   HP  Attack  Defense  \
# 162  163                    Mewtwo   Psychic    NaN  106     110       90
# 164  165             Mega Mewtwo Y   Psychic    NaN  106     150       70
# 262  263                    Raikou  Electric    NaN   90      85       75
# 263  264                     Entei      Fire    NaN  115     115       85
# 264  265                   Suicune     Water    NaN  100      75      115
# 414  415                  Regirock      Rock    NaN   80     100      200
# 415  416                    Regice       Ice    NaN   80      50      100
# 416  417                 Registeel     Steel    NaN   80      75      150
# 421  422                    Kyogre     Water    NaN  100     100       90
# 422  423             Primal Kyogre     Water    NaN  100     150       90
# 423  424                   Groudon    Ground    NaN  100     150      140
# 428  429       Deoxys Normal Forme   Psychic    NaN   50     150       50
# ...

# %%
len(df2)
# Out:
# 25

# %%
import numpy as np

# %%
lower = np.min(df['Attack'])

# %%
upper = np.max(df['Attack'])

# %%
limit = upper - lower

# %%
mean = np.mean(df['Attack'])

# %%
def standardize(x, x_mean, x_range):
    return (x - x_mean) / x_range

print(df['Attack'].apply(lambda x:standardize(x, mean, limit)))
# Out:
# 0     -0.162169
# 1     -0.091899
# 2      0.016209
# 3      0.113507
# 4     -0.145953
#          ...
# 795    0.113507
# 796    0.437831
# 797    0.167561
# 798    0.437831
# 799    0.167561
# Name: Attack, Length: 800, dtype: float64

# %%
lower = np.min(df2['Defense'])
print(lower)
# Out:
# 20

# %%
upper = np.max(df2['Defense'])
print(upper)
# Out:
# 200

# %%
limit = upper - lower

# %%
mean = np.mean(df2['Defense'])

# %%
def observe(n, n_mean, n_range):
    return (n - n_mean) / n_range

print(df2['Defense'].apply(lambda n:observe(n, mean, limit)))
# Out:
# 162   -0.054444
# 164   -0.165556
# 262   -0.137778
# 263   -0.082222
# 264    0.084444
# 414    0.556667
# 415    0.001111
# 416    0.278889
# 421   -0.054444
# 422   -0.054444
# 423    0.223333
# 428   -0.276667
# 429   -0.443333
# 430    0.334444
# 431   -0.054444
# 537    0.167778
# 538    0.028889
# 539   -0.165556
# 543    0.056667
# 549   -0.054444
# 550    0.001111
# 552    0.112222
# 702   -0.165556
# 703   -0.110000
# 792   -0.026667
# Name: Defense, dtype: float64

# %%
df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
print(df['Type 1'].apply(lambda x:x.lower()))
# Out:
# 0        grass
# 1        grass
# 2        grass
# 3        grass
# 4         fire
#         ...
# 795       rock
# 796       rock
# 797    psychic
# 798    psychic
# 799       fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.set_index('Name', inplace = True)

# %%
df.index = df.index.str.upper()

# %%
df
# Out:
#                   #   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# BULBASAUR         1    Grass  Poison  45      49       49       65       65
# IVYSAUR           2    Grass  Poison  60      62       63       80       80
# VENUSAUR          3    Grass  Poison  80      82       83      100      100
# MEGA VENUSAUR     4    Grass  Poison  80     100      123      122      120
# CHARMANDER        5     Fire     NaN  39      52       43       60       50
# ...             ...      ...     ...  ..     ...      ...      ...      ...
# DIANCIE         796     Rock   Fairy  50     100      150      100      150
# MEGA DIANCIE    797     Rock   Fairy  50     160      110      160      110
# HOOPA CONFINED  798  Psychic   Ghost  80     110       60      150      130
# HOOPA UNBOUND   799  Psychic    Dark  80     160       60      170      130
# VOLCANION       800     Fire   Water  80     110      120      130       90
#
#                 Speed  Generation  Legendary
# ...

# %%
df['Type 2'].apply(lambda x:x.lower() if isinstance(x, str) else None)
# Out:
# Name
# BULBASAUR         poison
# IVYSAUR           poison
# VENUSAUR          poison
# MEGA VENUSAUR     poison
# CHARMANDER          None
#                    ...
# DIANCIE            fairy
# MEGA DIANCIE       fairy
# HOOPA CONFINED     ghost
# HOOPA UNBOUND       dark
# VOLCANION          water
# Name: Type 2, Length: 800, dtype: object

# %%
df.groupby('Generation')

# %%
df.groupby(['Generation', 'Type 1'])

# %%
df.groupby('Generation').groups
# Out:
# {1: Index([       'BULBASAUR',          'IVYSAUR',         'VENUSAUR',
#            'MEGA VENUSAUR',       'CHARMANDER',       'CHARMELEON',
#                'CHARIZARD', 'MEGA CHARIZARD X', 'MEGA CHARIZARD Y',
#                 'SQUIRTLE',
#         ...
#                 'ARTICUNO',           'ZAPDOS',          'MOLTRES',
#                  'DRATINI',        'DRAGONAIR',        'DRAGONITE',
#                   'MEWTWO',    'MEGA MEWTWO X',    'MEGA MEWTWO Y',
#                      'MEW'],
#        dtype='object', name='Name', length=166),
#  2: Index(['CHIKORITA', 'BAYLEEF', 'MEGANIUM', 'CYNDAQUIL', 'QUILAVA',
#         'TYPHLOSION', 'TOTODILE', 'CROCONAW', 'FERALIGATR', 'SENTRET',
#         ...
#         'RAIKOU', 'ENTEI', 'SUICUNE', 'LARVITAR', 'PUPITAR', 'TYRANITAR',
#         'MEGA TYRANITAR', 'LUGIA', 'HO-OH', 'CELEBI'],
#        dtype='object', name='Name', length=106),
#  3: Index(['TREECKO', 'GROVYLE', 'SCEPTILE', 'MEGA SCEPTILE', 'TORCHIC',
# ...

# %%
df.columns
# Out:
# Index(['#', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.groupby('Generation')[['Sp. Atk']].median()
# Out:
#             Sp. Atk
# Generation
# 1                65
# 2                65
# 3                70
# 4                71
# 5                65
# 6                65

# %% [markdown]
# # or

# %%
df.groupby('Generation').agg({'Sp. Atk':'median'})
# Out:
#             Sp. Atk
# Generation
# 1                65
# 2                65
# 3                70
# 4                71
# 5                65
# 6                65

# %%
df.groupby('Generation').agg({'Sp. Atk':'sum'})
# Out:
#             Sp. Atk
# Generation
# 1             11922
# 2              6990
# 3             12129
# 4              9245
# 5             11878
# 6              6092

# %%
df.groupby('Generation')[['Sp. Atk']].median().sort_values(by = 'Sp. Atk', ascending =False)
# Out:
#             Sp. Atk
# Generation
# 4                71
# 3                70
# 1                65
# 2                65
# 5                65
# 6                65

# %%
df1 = df.groupby('Type 1').agg({'Speed':'median'})

# %%
print(df1)
# Out:
#           Speed
# Type 1
# Bug        60.0
# Dark       70.0
# Dragon     90.0
# Electric   88.0
# Fairy      45.0
# Fighting   60.0
# Fire       78.5
# Flying    116.0
# Ghost      60.5
# Grass      58.5
# Ground     65.0
# Ice        62.0
# Normal     71.0
# Poison     62.5
# Psychic    80.0
# Rock       50.0
# Steel      50.0
# Water      65.0

# %%
df1 = df1.sort_values(by = 'Speed', ascending = False)

# %%
fastest_type = df1.index[0]

# %%
print(fastest_type)
# Out:
# Flying

# %%
df2 = pd.pivot_table(df, index = 'Generation', values = 'Attack', aggfunc = 'sum')

# %%
print(df2)
# Out:
#             Attack
# Generation
# 1            12722
# 2             7635
# 3            13060
# 4            10027
# 5            13541
# 6             6216

# %%
df3 = pd.pivot_table(df, index = ['Legendary','Generation'], values = 'Attack')

# %%
print(df3)
# Out:
#                           Attack
# Legendary Generation
# False     1            74.981250
#           2            70.693069
#           3            76.971831
#           4            79.620370
#           5            78.246667
#           6            70.459459
# True      1           120.833333
#           2            99.000000
#           3           118.333333
#           4           109.846154
#           5           120.266667
#           6           125.250000

# %%
df4 = pd.pivot_table(df, index = ['Legendary','Generation'], values = ['Attack', 'HP'])

# %%
print(df4)
# Out:
#                           Attack          HP
# Legendary Generation
# False     1            74.981250   64.612500
#           2            70.693069   69.613861
#           3            76.971831   64.626761
#           4            79.620370   69.740741
#           5            78.246667   69.353333
#           6            70.459459   66.189189
# True      1           120.833333   98.000000
#           2            99.000000  103.400000
#           3           118.333333   81.666667
#           4           109.846154  100.846154
#           5           120.266667   96.133333
#           6           125.250000   87.500000

# %%
df5 = pd.pivot_table(df, index = 'Legendary', values = 'Attack', columns = 'Generation')

# %%
print(df5)
# Out:
# Generation           1          2           3           4           5  \
# Legendary
# False        74.981250  70.693069   76.971831   79.620370   78.246667
# True        120.833333  99.000000  118.333333  109.846154  120.266667
#
# Generation           6
# Legendary
# False        70.459459
# True        125.250000

# %%
df
# Out:
#                   #   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# BULBASAUR         1    Grass  Poison  45      49       49       65       65
# IVYSAUR           2    Grass  Poison  60      62       63       80       80
# VENUSAUR          3    Grass  Poison  80      82       83      100      100
# MEGA VENUSAUR     4    Grass  Poison  80     100      123      122      120
# CHARMANDER        5     Fire     NaN  39      52       43       60       50
# ...             ...      ...     ...  ..     ...      ...      ...      ...
# DIANCIE         796     Rock   Fairy  50     100      150      100      150
# MEGA DIANCIE    797     Rock   Fairy  50     160      110      160      110
# HOOPA CONFINED  798  Psychic   Ghost  80     110       60      150      130
# HOOPA UNBOUND   799  Psychic    Dark  80     160       60      170      130
# VOLCANION       800     Fire   Water  80     110      120      130       90
#
#                 Speed  Generation  Legendary
# ...

# %%
df1 = pd.DataFrame({'fruit': ['apple', 'banana', 'orange'] * 3,
                    'weight': ['high', 'medium', 'low'] * 3,
                    'price': np.random.randint(0, 15, 9)})

df2 = pd.DataFrame({'product': ['apple', 'orange', 'pine'] * 2,
                    'kilo': ['high', 'low'] * 3,
                    'price': np.random.randint(0, 15, 6)})

# %%
print(df1)
print(df2)
# Out:
#     fruit  weight  price
# 0   apple    high      3
# 1  banana  medium      2
# 2  orange     low     14
# 3   apple    high      4
# 4  banana  medium      3
# 5  orange     low      2
# 6   apple    high     14
# 7  banana  medium      0
# 8  orange     low      4
#   product  kilo  price
# 0   apple  high      8
# 1  orange   low     12
# 2    pine  high      0
# 3   apple   low      7
# 4  orange  high      8
# 5    pine   low      7

# %%
print(np.random.randint(0,15,9))
# Out:
# [ 7 12  9  3  6  1 11  1  8]

# %%
pd.merge(left = df1, right = df2, on = 'price', how = 'inner')
# Out:
#     fruit  weight  price product  kilo
# 0  banana  medium      0    pine  high

# %%
pd.merge(left = df1, right = df2, on = 'price', how = 'outer')
# Out:
#      fruit  weight  price product  kilo
# 0    apple    high      3     NaN   NaN
# 1   banana  medium      3     NaN   NaN
# 2   banana  medium      2     NaN   NaN
# 3   orange     low      2     NaN   NaN
# 4   orange     low     14     NaN   NaN
# 5    apple    high     14     NaN   NaN
# 6    apple    high      4     NaN   NaN
# 7   orange     low      4     NaN   NaN
# 8   banana  medium      0    pine  high
# 9      NaN     NaN      8   apple  high
# 10     NaN     NaN      8  orange  high
# 11     NaN     NaN     12  orange   low
# 12     NaN     NaN      7   apple   low
# 13     NaN     NaN      7    pine   low

# %%
pd.merge(left = df1, right = df2, on = 'price', how = 'left')
# Out:
#     fruit  weight  price product  kilo
# 0   apple    high      3     NaN   NaN
# 1  banana  medium      2     NaN   NaN
# 2  orange     low     14     NaN   NaN
# 3   apple    high      4     NaN   NaN
# 4  banana  medium      3     NaN   NaN
# 5  orange     low      2     NaN   NaN
# 6   apple    high     14     NaN   NaN
# 7  banana  medium      0    pine  high
# 8  orange     low      4     NaN   NaN

# %%
pd.merge(left = df1, right = df2, on = 'price', how = 'right')
# Out:
#     fruit  weight  price product  kilo
# 0  banana  medium      0    pine  high
# 1     NaN     NaN      8   apple  high
# 2     NaN     NaN      8  orange  high
# 3     NaN     NaN     12  orange   low
# 4     NaN     NaN      7   apple   low
# 5     NaN     NaN      7    pine   low

# %%
pd.merge(left = df1, right = df2, on = 'price', how = 'outer', indicator = True)
# Out:
#      fruit  weight  price product  kilo      _merge
# 0    apple    high      3     NaN   NaN   left_only
# 1   banana  medium      3     NaN   NaN   left_only
# 2   banana  medium      2     NaN   NaN   left_only
# 3   orange     low      2     NaN   NaN   left_only
# 4   orange     low     14     NaN   NaN   left_only
# 5    apple    high     14     NaN   NaN   left_only
# 6    apple    high      4     NaN   NaN   left_only
# 7   orange     low      4     NaN   NaN   left_only
# 8   banana  medium      0    pine  high        both
# 9      NaN     NaN      8   apple  high  right_only
# 10     NaN     NaN      8  orange  high  right_only
# 11     NaN     NaN     12  orange   low  right_only
# 12     NaN     NaN      7   apple   low  right_only
# 13     NaN     NaN      7    pine   low  right_only

# %%
merged = pd.merge(left = df1, right = df2, how = 'inner', left_on = ['fruit', 'weight'], right_on = ['product', 'kilo'], suffixes = ['_left', '_right'])
print(merged)
# Out:
#     fruit weight  price_left product  kilo  price_right
# 0   apple   high           3   apple  high            8
# 1   apple   high           4   apple  high            8
# 2   apple   high          14   apple  high            8
# 3  orange    low          14  orange   low           12
# 4  orange    low           2  orange   low           12
# 5  orange    low           4  orange   low           12

# %%
df
# Out:
#                   #   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# BULBASAUR         1    Grass  Poison  45      49       49       65       65
# IVYSAUR           2    Grass  Poison  60      62       63       80       80
# VENUSAUR          3    Grass  Poison  80      82       83      100      100
# MEGA VENUSAUR     4    Grass  Poison  80     100      123      122      120
# CHARMANDER        5     Fire     NaN  39      52       43       60       50
# ...             ...      ...     ...  ..     ...      ...      ...      ...
# DIANCIE         796     Rock   Fairy  50     100      150      100      150
# MEGA DIANCIE    797     Rock   Fairy  50     160      110      160      110
# HOOPA CONFINED  798  Psychic   Ghost  80     110       60      150      130
# HOOPA UNBOUND   799  Psychic    Dark  80     160       60      170      130
# VOLCANION       800     Fire   Water  80     110      120      130       90
#
#                 Speed  Generation  Legendary
# ...

# %%
Special_attack = pd.DataFrame(df[['Sp. Atk']])

# %%
print(Special_attack.head())
# Out:
#                Sp. Atk
# Name
# BULBASAUR           65
# IVYSAUR             80
# VENUSAUR           100
# MEGA VENUSAUR      122
# CHARMANDER          60

# %%
def attack(num):
    if num < 60:
        return 'Low Attack'
    elif (num >60 and num < 120):
        return 'Normal Attack'
    else:
        return 'High Attack'

print(Special_attack['Sp. Atk'].apply(attack))
# Out:
# Name
# BULBASAUR         Normal Attack
# IVYSAUR           Normal Attack
# VENUSAUR          Normal Attack
# MEGA VENUSAUR       High Attack
# CHARMANDER          High Attack
#                       ...
# DIANCIE           Normal Attack
# MEGA DIANCIE        High Attack
# HOOPA CONFINED      High Attack
# HOOPA UNBOUND       High Attack
# VOLCANION           High Attack
# Name: Sp. Atk, Length: 800, dtype: object
